# %%
import pandas as pd
import numpy as np
import scipy as stats

# %%
df = pd.read_excel('FDA.xlsx')
df
# Out:
#      classification          report_date         city  \
# 0         Class III  2012-06-20 00:00:00  Chadds Ford
# 1          Class II  2012-06-20 00:00:00        Miami
# 2          Class II  2012-06-20 00:00:00        Miami
# 3          Class II  2012-06-20 00:00:00        Miami
# 4          Class II  2012-06-20 00:00:00      Bedford
# ...             ...                  ...          ...
# 7385       Class II  2018-02-21 00:00:00         Cary
# 7386       Class II  2018-02-21 00:00:00         Cary
# 7387       Class II  2018-02-21 00:00:00         Cary
# 7388       Class II  2018-02-21 00:00:00         Cary
# 7389       Class II  2018-02-21 00:00:00         Cary
#
#                                    distribution_pattern openfda_brand_name  \
# 0                            Nationwide and Puerto Rico                NaN
# 1                           Nationwide and Puerto Rico.                NaN
# 2                           Nationwide and Puerto Rico.                NaN
# ...

# %%
df_state = df['state'].value_counts().head(10)
pd_state = pd.DataFrame(df_state)
pd_state.reset_index(level=0, inplace=True)
pd_state.columns = ['state', 'jumlah']
pd_state
# Out:
#   state  jumlah
# 0    IL     873
# 1    FL     848
# 2    TN     749
# 3    WA     740
# 4    NJ     581
# 5    CA     494
# 6    NY     298
# 7    AR     277
# 8    PA     267
# 9    TX     261

# %%
df_state.plot.bar(figsize=(20,5))

# %%
df_city = df['city'].value_counts().head(10)
pd_city = pd.DataFrame(df_city)
pd_city.reset_index(level=0, inplace=True)
pd_city.columns = ['city', 'jumlah']
pd_city
# Out:
#           city  jumlah
# 0    Vancouver     538
# 1    Knoxville     382
# 2  Lake Forest     344
# 3        Ocala     325
# 4      Newbern     299
# 5  Little Rock     215
# 6   Naperville     118
# 7  Noblesville     116
# 8      Houston     114
# 9      Orlando     111

# %%
df_city.plot.bar(figsize=(20,5))

# %%
# benar

# %%
df_drug = df['openfda_generic_name'].value_counts().head(10)
pd_drug = pd.DataFrame(df_drug)
pd_drug.reset_index(level=0, inplace=True)
pd_drug.columns = ['openfda_generic_name', 'jumlah']
pd_drug
# Out:
#                            openfda_generic_name  jumlah
# 0                               SODIUM CHLORIDE      39
# 1                          LEVOTHYROXINE SODIUM      27
# 2                               METHYLPHENIDATE      21
# 3                          ATORVASTATIN CALCIUM      13
# 4                     BUPIVACAINE HYDROCHLORIDE      13
# 5                                      PROPOFOL      13
# 6                                    LISINOPRIL      12
# 7                          DEXTROSE MONOHYDRATE      11
# 8  AMLODIPINE BESYLATE AND ATORVASTATIN CALCIUM      11
# 9                                   FLUCONAZOLE      10

# %%
df_drug.plot.bar(figsize=(20,5))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7390 entries, 0 to 7389
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   classification        7390 non-null   object
#  1   report_date           7388 non-null   object
#  2   city                  7387 non-null   object
#  3   distribution_pattern  7385 non-null   object
#  4   openfda_brand_name    976 non-null    object
#  5   openfda_generic_name  976 non-null    object
#  6   state                 7308 non-null   object
# dtypes: object(7)
# memory usage: 404.3+ KB

# %%
df.groupby('state').count().mean()
# Out:
# classification          158.869565
# report_date             158.869565
# city                    158.869565
# distribution_pattern    158.869565
# openfda_brand_name       21.130435
# openfda_generic_name     21.130435
# dtype: float64

# %%
df_group= df['classification'].value_counts().head(10)
pd_group = pd.DataFrame(df_group)
pd_group.reset_index(level=0, inplace=True)
pd_group.columns = ['classification', 'jumlah']
pd_group
# Out:
#                                       classification  jumlah
# 0                                           Class II    5986
# 1                                          Class III     834
# 2                                            Class I     567
# 3   04192016:29  04112016:76  04192016:49  041920...       1
# 4  42016:78  06142016:55  05042016:78  05042016:7...       1
# 5  16:80  02082016:93  02082016:93  02092016:80  ...       1

# %%
df_group = df.groupby('state').count()
df_group
# Out:
#        classification  report_date  city  distribution_pattern  \
# state
# AL                137          137   137                   137
# AR                277          277   277                   277
# AZ                122          122   122                   122
# CA                494          494   494                   494
# CO                 16           16    16                    16
# CT                 16           16    16                    16
# DE                  6            6     6                     6
# FL                848          848   848                   848
# GA                 81           81    81                    81
# IA                 63           63    63                    63
# ID                 11           11    11                    11
# IL                873          873   873                   873
# IN                166          166   166                   166
# KS                 22           22    22                    22
# ...

# %%
df_group['classification'].mean()
# Out:
# 158.8695652173913

# %%
df_group['classification'].describe()
# Out:
# count     46.000000
# mean     158.869565
# std      237.102192
# min        1.000000
# 25%       16.000000
# 50%       49.500000
# 75%      181.000000
# max      873.000000
# Name: classification, dtype: float64

# %%
arr_a = df.to_numpy()

arr_il = []

for i in range(len(arr_a)):
  if arr_a[i][-1] == "IL":
    arr_il.append(arr_a[i])

arr_il
# Out:
# [array(['Class II', datetime.datetime(2012, 6, 20, 0, 0), 'Lake Forest',
#         'Nationwide.', 'PROPOFOL', 'PROPOFOL', 'IL'], dtype=object),
#  array(['Class II', datetime.datetime(2012, 6, 27, 0, 0), 'Abbott Park',
#         'Nationwide', 'ZEMPLAR', 'PARICALCITOL', 'IL'], dtype=object),
#  array(['Class III', datetime.datetime(2012, 6, 27, 0, 0), 'Lake Forest',
#         'Nationwide', 'MAGNESIUM SULFATE IN WATER',
#         'MAGNESIUM SULFATE IN WATER', 'IL'], dtype=object),
#  array(['Class I', datetime.datetime(2012, 7, 25, 0, 0), 'Lake Forest',
#         'Nationwide', nan, nan, 'IL'], dtype=object),
#  array(['Class III', datetime.datetime(2012, 7, 25, 0, 0), 'Buffalo Grove',
#         'Nationwide', 'CIPROFLOXACIN', 'CIPROFLOXACIN', 'IL'], dtype=object),
#  array(['Class I', datetime.datetime(2012, 8, 15, 0, 0), 'Lake Forest',
#         'Nationwide.', 'HYDROMORPHONE HYDROCHLORIDE',
#         'HYDROMORPHONE HYDROCHLORIDE', 'IL'], dtype=object),
# ...

# %%
df_il = pd.DataFrame(arr_il)
df_il.columns = ['classification', 'report_date', 'city', 'distribution_pattern', 'openfda_brand_name', 'openfda_generic_name', 'state']
df_il
# Out:
#     classification report_date           city  \
# 0         Class II  2012-06-20    Lake Forest
# 1         Class II  2012-06-27    Abbott Park
# 2        Class III  2012-06-27    Lake Forest
# 3          Class I  2012-07-25    Lake Forest
# 4        Class III  2012-07-25  Buffalo Grove
# ..             ...         ...            ...
# 868       Class II  2018-02-21           Cary
# 869       Class II  2018-02-21           Cary
# 870       Class II  2018-02-21           Cary
# 871       Class II  2018-02-21           Cary
# 872       Class II  2018-02-21           Cary
#
#                                   distribution_pattern  \
# 0                                          Nationwide.
# 1                                           Nationwide
# 2                                           Nationwide
# 3                                           Nationwide
# 4                                           Nationwide
# ..                                                 ...
# ...

# %%
df_narkoba = df_il['openfda_generic_name'].value_counts().head(10)
df_narkoba = pd.DataFrame(df_narkoba)
df_narkoba.reset_index(level=0, inplace=True)

df_narkoba.columns = ['openfda_generic_name', 'jumlah']
df_narkoba
# Out:
#           openfda_generic_name  jumlah
# 0              SODIUM CHLORIDE      37
# 1                     PROPOFOL      13
# 2    BUPIVACAINE HYDROCHLORIDE      13
# 3         DEXTROSE MONOHYDRATE      11
# 4       KETOROLAC TROMETHAMINE       7
# 5      LIDOCAINE HYDROCHLORIDE       7
# 6  HYDROMORPHONE HYDROCHLORIDE       6
# 7               HEPARIN SODIUM       6
# 8     VANCOMYCIN HYDROCHLORIDE       5
# 9           LEUPROLIDE ACETATE       5

# %%
arr_df = df.to_numpy()
arr_va = []

for i in range(len(arr_df)):
  if arr_df[i][2] == 'Vancouver':
    arr_va.append(arr_df[i])
arr_va
# Out:
# [array(['Class II', datetime.datetime(2014, 1, 22, 0, 0), 'Vancouver',
#         'Repacked drugs were distributed in Arizona, California, Oregon, and Washington.',
#         nan, nan, 'WA'], dtype=object),
#  array(['Class II', datetime.datetime(2014, 1, 22, 0, 0), 'Vancouver',
#         'Repacked drugs were distributed in Arizona, California, Oregon, and Washington.',
#         nan, nan, 'WA'], dtype=object),
#  array(['Class II', datetime.datetime(2014, 1, 22, 0, 0), 'Vancouver',
#         'Repacked drugs were distributed in Arizona, California, Oregon, and Washington.',
#         nan, nan, 'WA'], dtype=object),
#  array(['Class II', datetime.datetime(2014, 1, 22, 0, 0), 'Vancouver',
#         'Repacked drugs were distributed in Arizona, California, Oregon, and Washington.',
#         nan, nan, 'WA'], dtype=object),
#  array(['Class II', datetime.datetime(2014, 1, 22, 0, 0), 'Vancouver',
#         'Repacked drugs were distributed in Arizona, California, Oregon, and Washington.',
# ...

# %%
df_va = pd.DataFrame(arr_va)
df_va.columns = ['classification', 'report_date', 'city', 'distribution_pattern', 'openfd_brand_name', 'openfda_generic_name', 'state']
df_va
# Out:
#     classification report_date       city  \
# 0         Class II  2014-01-22  Vancouver
# 1         Class II  2014-01-22  Vancouver
# 2         Class II  2014-01-22  Vancouver
# 3         Class II  2014-01-22  Vancouver
# 4         Class II  2014-01-22  Vancouver
# ..             ...         ...        ...
# 533       Class II  2014-01-29  Vancouver
# 534       Class II  2014-01-29  Vancouver
# 535       Class II  2014-01-29  Vancouver
# 536       Class II  2014-01-29  Vancouver
# 537       Class II  2014-05-21  Vancouver
#
#                                   distribution_pattern  openfd_brand_name  \
# 0    Repacked drugs were distributed in Arizona, Ca...                NaN
# 1    Repacked drugs were distributed in Arizona, Ca...                NaN
# 2    Repacked drugs were distributed in Arizona, Ca...                NaN
# 3    Repacked drugs were distributed in Arizona, Ca...                NaN
# 4    Repacked drugs were distributed in Arizona, Ca...                NaN
# ...

# %%
df_narkoba = df_va['openfda_generic_name'].value_counts().head(10)
df_narkoba = pd.DataFrame(df_narkoba)
df_narkoba.reset_index(level=0, inplace=True)

df_narkoba.columns = ['openfda_generic_name', 'jumlah']
df_narkoba
# Out:
# Empty DataFrame
# Columns: [openfda_generic_name, jumlah]
# Index: []
